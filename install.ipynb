# %%
# %pip install -r requirements.txt
# Out:
# ...
#      ---------------------------------------- 0.0/244.0 kB ? eta -:--:--
#      ---- -------------------------------- 30.7/244.0 kB 660.6 kB/s eta 0:00:01
#      ---------------------------- --------- 184.3/244.0 kB 1.9 MB/s eta 0:00:01
#      -------------------------------------- 244.0/244.0 kB 1.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/144.2 kB ? eta -:--:--
#      -------------------------------------- 144.2/144.2 kB 8.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/296.7 kB ? eta -:--:--
#      ------------------------------------- 296.7/296.7 kB 19.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/228.6 kB ? eta -:--:--
#      ---------------------------------------- 228.6/228.6 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 0.0/383.2 kB ? eta -:--:--
#      -------------------------------------- 383.2/383.2 kB 7.9 MB/s eta 0:00:00
# ...
